# %%
# !pip install streamlit pandas scikit-learn matplotlib seaborn joblib transformers torch evaluate

# %%
# !unzip mbert_scam_model.zip -d mbert_scam_model
# !unzip mbert_scam_tokenizer.zip -d mbert_scam_tokenizer

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

model_dir = "/content/mbert_scam_model"
tokenizer_dir = model_dir

tokenizer = AutoTokenizer.from_pretrained(tokenizer_dir)
model = AutoModelForSequenceClassification.from_pretrained(model_dir)
pipe = pipeline("text-classification", model=model, tokenizer=tokenizer)

print(pipe("This is a scam message, click here!"))

# %%
# !pip install streamlit pyngrok

# %%
# !ngrok config add-authtoken     # enter authtoken here

# %%
from pyngrok import ngrok
import threading
import subprocess

# Run Streamlit in a background thread
def run_streamlit():
    subprocess.run(["streamlit", "run", "app.py", "--server.port", "8501"])
threading.Thread(target=run_streamlit).start()

# Create a public URL
public_url = ngrok.connect(8501)
print(f"Streamlit app is live at: {public_url}")
